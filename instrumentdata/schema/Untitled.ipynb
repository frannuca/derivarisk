# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(-10,10,100)
y= [s**(2.0) for s in x ] 
plt.plot(x,y)
plt.title("x**2")
plt.show()

# %%
-0.11**(1.0/3.0)
# Out:
# -0.4791419857062784
